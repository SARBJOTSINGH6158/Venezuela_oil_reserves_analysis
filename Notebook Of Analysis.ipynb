# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\sarbj\Downloads\Reservoir_NameBasin_RegionLocatio (1).csv')

# %%
df.head()
# Out:
#          Reservoir_Name  Basin_Region  \
# 0  Orinoco Belt (Total)  Orinoco Belt
# 1      Carabobo-2 North  Orinoco Belt
# 2       Carabobo-4 West  Orinoco Belt
# 3         Junin Block 6  Orinoco Belt
# 4         Junin Block 4  Orinoco Belt
#
#                                          Location  \
# 0  Eastern Venezuela (Anzoategui-Monagas-Guarico)
# 1                                  Carabobo State
# 2                                  Carabobo State
# 3                                Anzoategui State
# 4                                Anzoategui State
#
#    Proven_Reserves_Billion_Barrels  \
# 0                            235.0
# 1                              6.5
# 2                              6.5
# 3                              8.0
# 4                              7.0
#
#   Estimated_Recoverable_Reserves_Billion_Barrels  \
# 0                                  100.00-270.00
# 1                                            2.5
# 2                                            2.5
# ...

# %%
df.columns = df.columns.str.lower().str.replace(" ", "_")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 11 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   reservoir_name                                  23 non-null     object
#  1   basin_region                                    23 non-null     object
#  2   location                                        23 non-null     object
#  3   proven_reserves_billion_barrels                 23 non-null     float64
#  4   estimated_recoverable_reserves_billion_barrels  23 non-null     object
#  5   production_capacity_barrels_day                 23 non-null     int64
#  6   oil_type_grade                                  23 non-null     object
#  7   status                                          23 non-null     object
#  8   major_operators                                 23 non-null     object
# ...

# %%
#As data is clean no further cleaning required
#I only changed the column names to lowercase and replaced spaces with underscores for better accessibility.

# %%
df.shape
# Out:
# (23, 11)

# %%
#also it is not that mush data so no need of optimizing memory usage

# %%
df.head(23)
# Out:
#            reservoir_name     basin_region  \
# 0    Orinoco Belt (Total)     Orinoco Belt
# 1        Carabobo-2 North     Orinoco Belt
# 2         Carabobo-4 West     Orinoco Belt
# 3           Junin Block 6     Orinoco Belt
# 4           Junin Block 4     Orinoco Belt
# 5           Junin Block 5     Orinoco Belt
# 6                 Machete     Orinoco Belt
# 7                   Zuata     Orinoco Belt
# 8                  Hamaca     Orinoco Belt
# 9             Cerro Negro     Orinoco Belt
# 10        Maracaibo Basin  Maracaibo Basin
# 11  Lake Maracaibo Fields  Maracaibo Basin
# 12    Barinas-Apure Basin      Apure Basin
# 13           Falcon Basin     Falcon Basin
# 14             El Furrial    Oriente Basin
# 15                Musipan    Oriente Basin
# 16         Punta Pescador    Oriente Basin
# 17       Quiriquire Field    Oriente Basin
# 18        Tia Juana Field  Maracaibo Basin
# 19           Boscán Field      Zulia Basin
# 20           Dacion Field    Oriente Basin
# ...
